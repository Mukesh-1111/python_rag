# %%
doc=Document(
    page_content="This is a sample document.",
    metadata={
        "source": "generated",
        "page": 1,
        "author": "ChatGPT",
        "date_created": "2024-06-15"
        
        }
)
doc
# Out:
# Document(metadata={'source': 'generated', 'page': 1, 'author': 'ChatGPT', 'date_created': '2024-06-15'}, page_content='This is a sample document.')

# %%
from langchain_core.documents import Document
